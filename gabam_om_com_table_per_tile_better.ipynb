# %%
library(tidyverse)


#all input pathways
# in_paths = c('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/om_com_2015_64_32',
#              '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/om_com_2015_128_32',
#              '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/om_com_2015_256_64',
#              '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/om_com_2015_450_64',
#              '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/om_com_2015_compare_combined',
#              '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/om_com_2015_compare_combined2_median'
#          )


in_paths = c('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/om_com_2015_128_32')

final = list()

# in_path = '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/om_com_2015_better'

#loop through each path and get stats
# for(in_path in in_paths){
    
    

#read all in at once
df = list.files(in_path, full.names = T, pattern = "*.csv") %>%  map_df(~read_csv(., col_select = c('Area', 'Class', 'Band', 'Year'), col_types = cols()))

#groupby by the year and get total intersection, omission and comission
df = df %>% group_by(Band, Class) %>% summarize(Area = sum(Area))


# # #get the total burned area (verify with polygons it matches), the files are in m2, convert to mHa (m2 * 0.0001) / 1e6
df = df %>% mutate(Area = Area * 0.0001 / 1e6)

# #lfdb fire area
lfdb_area = df %>% filter(Class == 'Fire_Area')


# #now find out which percent for us and gabam is intersecting, omission and comission
gabam = df %>% filter(Class %in% c('Gabam_Com', 'Gabam_Int', 'Gabam_Om'))
us =  df %>% filter(Class %in% c('Us_Com', 'Us_Int', 'Us_Om'))


gabam_pct = gabam %>% group_by(Band) %>% mutate(Percent = Area / sum(Area))
us_pct = us %>% group_by(Band) %>% mutate(Percent = Area / sum(Area))



comb = bind_rows(us_pct, gabam_pct)
comb = bind_rows(comb, lfdb_area)

# splits = str_split(in_path, '_')[[1]]
# size1 = splits[6]
# size2 = splits[7]

# ext = paste0(size1, '_', size2)
# comb$Tile_Size = ext
    
    
# }


final = comb %>% distinct(Class, Area, Percent, .keep_all = TRUE) %>% mutate(Location = 'AK_2015')

write_csv(final, '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/ak_2015_gabam_compare_better.csv')
final
# Out:
# Error in `group_by()`:
# ! Must group by variables found in `.data`.
# Column `Band` is not found.
# Column `Class` is not found.
# Traceback:
#
# 1. df %>% group_by(Band, Class) %>% summarize(Area = sum(Area))
# 2. summarize(., Area = sum(Area))
# 3. group_by(., Band, Class)
# 4. group_by.data.frame(., Band, Class)
# 5. group_by_prepare(.data, ..., .add = .add, caller_env = caller_env())
# 6. abort(bullets, call = error_call)
# 7. signal_abort(cnd, .file)

# %%
library(tidyverse)


#all input pathways
in_paths = c('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/om_com_2014_64_32',
             '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/om_com_2014_128_32',
             '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/om_com_2014_256_64',
             '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/om_com_2014_450_64',
             '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/om_com_2014_compare_combined',
             '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/om_com_2014_compare_combined2_median'
         )


in_path = '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/om_com_2014_better'

 
    

#read all in at once
df = list.files(in_path, full.names = T, pattern = "*.csv") %>%  map_df(~read_csv(., col_select = c('Area', 'Class', 'Band', 'Year'), col_types = cols()))

#groupby by the year and get total intersection, omission and comission
df = df %>% group_by(Band, Class) %>% summarize(Area = sum(Area))


# # #get the total burned area (verify with polygons it matches), the files are in m2, convert to mHa (m2 * 0.0001) / 1e6
df = df %>% mutate(Area = Area * 0.0001 / 1e6)

# #lfdb fire area
lfdb_area = df %>% filter(Class == 'Fire_Area')


# #now find out which percent for us and gabam is intersecting, omission and comission
gabam = df %>% filter(Class %in% c('Gabam_Com', 'Gabam_Int', 'Gabam_Om'))
us =  df %>% filter(Class %in% c('Us_Com', 'Us_Int', 'Us_Om'))


gabam_pct = gabam %>% group_by(Band) %>% mutate(Percent = Area / sum(Area))
us_pct = us %>% group_by(Band) %>% mutate(Percent = Area / sum(Area))



comb = bind_rows(us_pct, gabam_pct)
comb = bind_rows(comb, lfdb_area)





final = comb %>% distinct(Class, Area, Percent, .keep_all = TRUE) %>% mutate(Location = 'NWT_2014')

write_csv(final, '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nwt_2014_gabam_compare_better.csv')
final
# Out:
# `summarise()` has grouped output by 'Band'. You can override using the
# `.groups` argument.
#    Band            Class     Area       Percent     Location
# 1  b128_32         Us_Com    0.4068876  0.1277195   NWT_2014
# 2  b128_32         Us_Int    2.1025834  0.6599877   NWT_2014
# 3  b128_32         Us_Om     0.6763207  0.2122928   NWT_2014
# 4  b128_64         Us_Com    0.3975390  0.1251523   NWT_2014
# 5  b128_64         Us_Int    2.1114503  0.6647216   NWT_2014
# 6  b128_64         Us_Om     0.6674538  0.2101262   NWT_2014
# 7  b256_128        Us_Com    0.3872093  0.1222980   NWT_2014
# 8  b256_128        Us_Int    2.0941939  0.6614399   NWT_2014
# 9  b256_128        Us_Om     0.6847102  0.2162621   NWT_2014
# 10 b256_128_64     Us_Com    0.4026683  0.1265627   NWT_2014
# 11 b256_128_64     Us_Int    2.1331961  0.6704848   NWT_2014
# 12 b256_128_64     Us_Om     0.6457080  0.2029525   NWT_2014
# 13 b256_64         Us_Com    0.3918807  0.1235911   NWT_2014
# 14 b256_64         Us_Int    2.0834568  0.6570792   NWT_2014
# 15 b256_64         Us_Om     0.6954473  0.2193297   NWT_2014
# 16 b512_0          Us_Com    0.3837813  0.1213467   NWT_2014
# 17 b512_0          Us_Int    2.0540786  0.6494729   NWT_2014
# 18 b512_0          Us_Om     0.7248255  0.2291804   NWT_2014
# 19 b512_128        Us_Com    0.3724416  0.1181849   NWT_2014
# 20 b512_128        Us_Int    2.0759661  0.6587554   NWT_2014
# 21 b512_128        Us_Om     0.7029380  0.2230596   NWT_2014
# 22 b512_256        Us_Com    0.3710563  0.1177971   NWT_2014
# 23 b512_256        Us_Int    2.0619576  0.6545979   NWT_2014
# 24 b512_256        Us_Om     0.7169465  0.2276049   NWT_2014
# 25 b512_256_128_64 Us_Com    0.3911768  0.1233965   NWT_2014
# 26 b512_256_128_64 Us_Int    2.1271193  0.6709984   NWT_2014
# 27 b512_256_128_64 Us_Om     0.6517848  0.2056051   NWT_2014
# 28 b64_32          Us_Com    0.4241241  0.1324135   NWT_2014
# 29 b64_32          Us_Int    2.0973470  0.6548013   NWT_2014
# 30 b64_32          Us_Om     0.6815571  0.2127852   NWT_2014
# ⋮  ⋮               ⋮         ⋮          ⋮           ⋮
# 41 b256_128_64     Gabam_Int 1.45203556 0.520197246 NWT_2014
# 42 b256_128_64     Gabam_Om  1.32686854 0.475355689 NWT_2014
# 43 b256_64         Gabam_Com 0.01241317 0.004447065 NWT_2014
# 44 b256_64         Gabam_Int 1.45203556 0.520197246 NWT_2014
# 45 b256_64         Gabam_Om  1.32686854 0.475355689 NWT_2014
# 46 b512_0          Gabam_Com 0.01241317 0.004447065 NWT_2014
# 47 b512_0          Gabam_Int 1.45203556 0.520197246 NWT_2014
# 48 b512_0          Gabam_Om  1.32686854 0.475355689 NWT_2014
# 49 b512_128        Gabam_Com 0.01241317 0.004447065 NWT_2014
# 50 b512_128        Gabam_Int 1.45203556 0.520197246 NWT_2014
# 51 b512_128        Gabam_Om  1.32686854 0.475355689 NWT_2014
# 52 b512_256        Gabam_Com 0.01241317 0.004447065 NWT_2014
# 53 b512_256        Gabam_Int 1.45203556 0.520197246 NWT_2014
# 54 b512_256        Gabam_Om  1.32686854 0.475355689 NWT_2014
# 55 b512_256_128_64 Gabam_Com 0.01241317 0.004447065 NWT_2014
# 56 b512_256_128_64 Gabam_Int 1.45203556 0.520197246 NWT_2014
# 57 b512_256_128_64 Gabam_Om  1.32686854 0.475355689 NWT_2014
# 58 b64_32          Gabam_Com 0.01241317 0.004447065 NWT_2014
# 59 b64_32          Gabam_Int 1.45203556 0.520197246 NWT_2014
# 60 b64_32          Gabam_Om  1.32686854 0.475355689 NWT_2014
# 61 b128_32         Fire_Area 2.77890410          NA NWT_2014
# 62 b128_64         Fire_Area 2.77890410          NA NWT_2014
# 63 b256_128        Fire_Area 2.77890410          NA NWT_2014
# 64 b256_128_64     Fire_Area 2.77890410          NA NWT_2014
# 65 b256_64         Fire_Area 2.77890410          NA NWT_2014
# 66 b512_0          Fire_Area 2.77890410          NA NWT_2014
# 67 b512_128        Fire_Area 2.77890410          NA NWT_2014
# 68 b512_256        Fire_Area 2.77890410          NA NWT_2014
# 69 b512_256_128_64 Fire_Area 2.77890410          NA NWT_2014
# 70 b64_32          Fire_Area 2.77890410          NA NWT_2014
